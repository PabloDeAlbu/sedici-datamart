# %% [markdown]
# Utilizamos la herramienta librería [Scholarly](https://scholarly.readthedocs.io/)

# %%
from scholarly import scholarly

# %%
orgs = scholarly.search_org('Universidad Nacional de La Plata')
orgs
# Out:
# [{'Organization': 'National University of La Plata',
#   'id': '18050997564342690566'}]

# %%
search_query = scholarly.search_author_by_organization(orgs[0]['id'])
search_query
# Out:
# <generator object Navigator.search_authors at 0x7f811efa90b0>

# %%
author = next(search_query)
author
# Out:
# {'container_type': 'Author',
#  'filled': [],
#  'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#  'scholar_id': 'hBj_cToAAAAJ',
#  'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=hBj_cToAAAAJ',
#  'name': 'Fernando Monticelli',
#  'affiliation': 'Universidad Nacional de La Plata',
#  'email_domain': '@fisica.unlp.edu.ar',
#  'interests': ['Física de partículas', 'LHC', 'higgs', 'ATLAS'],
#  'citedby': 241495}

# %%
result = scholarly.fill(author, sections=['basics', 'indices', 'counts', 'coauthors', 'publications', 'public_access'])
result
# Out:
# {'container_type': 'Author',
#  'filled': ['indices',
#   'coauthors',
#   'basics',
#   'publications',
#   'public_access',
#   'counts'],
#  'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#  'scholar_id': 'hBj_cToAAAAJ',
#  'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=hBj_cToAAAAJ',
#  'name': 'Fernando Monticelli',
#  'affiliation': 'Universidad Nacional de La Plata',
#  'email_domain': '@fisica.unlp.edu.ar',
#  'interests': ['Física de partículas', 'LHC', 'higgs', 'ATLAS'],
#  'citedby': 241495,
#  'citedby5y': 136170,
#  'hindex': 229,
#  'hindex5y': 170,
#  'i10index': 1023,
#  'i10index5y': 899,
#  'coauthors': [],
#  'organization': 18050997564342690566,
#  'publications': [{'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Observation of a new particle in the search for the Standard Model Higgs boson with the ATLAS detector at the LHC',
#     'pub_year': '2012',
#     'citation': 'Physics Letters B 716 (1), 1-29, 2012'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:35N4QoGY0k4C',
#    'num_citations': 21285,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1650605866782918575,12208398159265531045,7002439371836982649,8161419268094180087,8274606671386213419,4129879110990296975,431379868423623389,5515864274333832935,13014053882874396684,5361780478681219460,11174544795154369691,4135087345251554704,17921993071624645290,12862490021668437088,17628821927540691258,5947814863875902686,12995586479577048271,2247089412673132293,1971151425299117470,12572656595895527424',
#    'cites_id': ['1650605866782918575',
#     '12208398159265531045',
#     '7002439371836982649',
#     '8161419268094180087',
#     '8274606671386213419',
#     '4129879110990296975',
#     '431379868423623389',
#     '5515864274333832935',
#     '13014053882874396684',
#     '5361780478681219460',
#     '11174544795154369691',
#     '4135087345251554704',
#     '17921993071624645290',
#     '12862490021668437088',
#     '17628821927540691258',
#     '5947814863875902686',
#     '12995586479577048271',
#     '2247089412673132293',
#     '1971151425299117470',
#     '12572656595895527424']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'The ATLAS experiment at the CERN large hadron collider',
#     'pub_year': '2008',
#     'citation': 'Journal of instrumentation 3 (S08003), 2008'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:kuK5TVdYjLIC',
#    'num_citations': 15132,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4583933401305623738,3466080295819433472,6224329931004518504',
#    'cites_id': ['4583933401305623738',
#     '3466080295819433472',
#     '6224329931004518504']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'The ATLAS simulation infrastructure',
#     'pub_year': '2010',
#     'citation': 'The European Physical Journal C 70 (3), 823-874, 2010'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:s9ia6_kGH2AC',
#    'num_citations': 7034,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10614936945083796742,5262437448071889017',
#    'cites_id': ['10614936945083796742', '5262437448071889017']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Performance of the ATLAS trigger system in 2015',
#     'pub_year': '2017',
#     'citation': 'The European Physical Journal C 77 (5), 1-53, 2017'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:kUhpeDhEZMUC',
#    'num_citations': 4074,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12841760951602738711,1783753979756688926,17248375628814774623,4976964920695193403,8059014344525053599,8430453384709171544,5678964546097994813,8037492879490099474',
#    'cites_id': ['12841760951602738711',
#     '1783753979756688926',
#     '17248375628814774623',
#     '4976964920695193403',
#     '8059014344525053599',
#     '8430453384709171544',
#     '5678964546097994813',
#     '8037492879490099474']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Performance of missing transverse momentum reconstruction in proton-proton collisions at  with ATLAS',
#     'pub_year': '2012',
#     'citation': 'The European Physical Journal C 72 (1), 1-35, 2012'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:F1b5ZUV5XREC',
#    'num_citations': 2902,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6765814868791416441,16912577831440217489,7407504299594214695,18128401047178100965,12059637938015228677',
#    'cites_id': ['6765814868791416441',
#     '16912577831440217489',
#     '7407504299594214695',
#     '18128401047178100965',
#     '12059637938015228677']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Improved luminosity determination in pp collisions at  using the ATLAS detector at the LHC',
#     'pub_year': '2013',
#     'citation': 'The European Physical Journal C 73 (8), 1-39, 2013'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:YvgfBAebZEkC',
#    'num_citations': 2882,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11477579481550698253,16158292068729758796,17955917586703059120,3524354228106105,15535073049402440963,8476634620043485885,9852360725533101306,9582163425444559904,8041806702459002145',
#    'cites_id': ['11477579481550698253',
#     '16158292068729758796',
#     '17955917586703059120',
#     '3524354228106105',
#     '15535073049402440963',
#     '8476634620043485885',
#     '9852360725533101306',
#     '9582163425444559904',
#     '8041806702459002145']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Muon reconstruction performance of the ATLAS detector in proton–proton collision data at  s =13 TeV',
#     'pub_year': '2016',
#     'citation': 'The European Physical Journal C 76 (5), 1-30, 2016'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:VOx2b1Wkg3QC',
#    'num_citations': 2559,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1269740065448150341,4043268828788431603',
#    'cites_id': ['1269740065448150341', '4043268828788431603']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Jet energy measurement with the ATLAS detector in proton-proton collisions at sqrt (s)= 7 TeV',
#     'pub_year': '2011',
#     'citation': 'arXiv preprint arXiv:1112.6426, 2011'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:4hFrxpcac9AC',
#    'num_citations': 2315,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8688341884557145987,5651138599710101302,3816039257808381918,8611367672164492354',
#    'cites_id': ['8688341884557145987',
#     '5651138599710101302',
#     '3816039257808381918',
#     '8611367672164492354']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of  production with a veto on additional central jet activity in pp collisions at  TeV using the ATLAS detector',
#     'pub_year': '2012',
#     'citation': 'The European Physical Journal C 72 (6), 1-24, 2012'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:Y9VhQm-5nPIC',
#    'num_citations': 2271,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16371391559457474341,6056251129256414436,8109248270637852614,5544739820936024242,3363960316029559772,3306517186872528400,5358027457006360637,7828499199417900461,12159291689375749554,14169702696304888074,18056113951993063397,6356764624437676356,13711470652506676708,15782620185586266211,10050368125832395160,2369343048533026575,11583900645120074805,14066345624649225357,10005509953211226129,3711477456535955752,1374818078589048835,11565892672934341254,9302077052940011349,3983183621428756023,17476758921603038300,8376058019211824846,5892643560942527478,2109177678676791862,11474744108753089090',
#    'cites_id': ['16371391559457474341',
#     '6056251129256414436',
#     '8109248270637852614',
#     '5544739820936024242',
#     '3363960316029559772',
#     '3306517186872528400',
#     '5358027457006360637',
#     '7828499199417900461',
#     '12159291689375749554',
#     '14169702696304888074',
#     '18056113951993063397',
#     '6356764624437676356',
#     '13711470652506676708',
#     '15782620185586266211',
#     '10050368125832395160',
#     '2369343048533026575',
#     '11583900645120074805',
#     '14066345624649225357',
#     '10005509953211226129',
#     '3711477456535955752',
#     '1374818078589048835',
#     '11565892672934341254',
#     '9302077052940011349',
#     '3983183621428756023',
#     '17476758921603038300',
#     '8376058019211824846',
#     '5892643560942527478',
#     '2109177678676791862',
#     '11474744108753089090']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Expected performance of the ATLAS experiment-detector, trigger and physics',
#     'pub_year': '2008',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:MXK_kJrjxJIC',
#    'num_citations': 2232,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=452481873063125376',
#    'cites_id': ['452481873063125376']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Electron efficiency measurements with the ATLAS detector using 2012 LHC proton-proton collision data',
#     'pub_year': '2016',
#     'citation': 'arXiv preprint arXiv:1612.01456, 2016'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:ZHo1McVdvXMC',
#    'num_citations': 2132,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13961136281933398322,1762831469858059875',
#    'cites_id': ['13961136281933398322', '1762831469858059875']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Topological cell clustering in the ATLAS calorimeters and its performance in LHC Run 1',
#     'pub_year': '2017',
#     'citation': 'The European Physical Journal C 77 (7), 1-73, 2017'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:VRfTbSk87rEC',
#    'num_citations': 2066,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12808183623084625274,15252644844416254535,5092592383726332706',
#    'cites_id': ['12808183623084625274',
#     '15252644844416254535',
#     '5092592383726332706']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Performance of pile-up mitigation techniques for jets in  p p collisions at  s = 8  TeV using the ATLAS detector',
#     'pub_year': '2016',
#     'citation': 'The European Physical Journal C 76 (11), 1-36, 2016'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:7uOkfv6XYJ4C',
#    'num_citations': 2035,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11101651974264572444,17644278616689289912,12029158581657067957,10950275186628724381,5164744136113064809',
#    'cites_id': ['11101651974264572444',
#     '17644278616689289912',
#     '12029158581657067957',
#     '10950275186628724381',
#     '5164744136113064809']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Combined Measurement of the Higgs Boson Mass in  Collisions at  and 8 TeV with the ATLAS and CMS Experiments',
#     'pub_year': '2015',
#     'citation': 'Physical review letters 114 (19), 191803, 2015'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:_kc_bZDykSQC',
#    'num_citations': 1911,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=663243022798658468,6229988113308439302',
#    'cites_id': ['663243022798658468', '6229988113308439302']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Jet energy measurement and its systematic uncertainty in proton–proton collisions at  s = 7  TeV with the ATLAS detector',
#     'pub_year': '2015',
#     'citation': 'The European Physical Journal C 75 (1), 1-101, 2015'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:vDijr-p_gm4C',
#    'num_citations': 1760,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1351220655882479798,16940164747902333609,16507853878702409840',
#    'cites_id': ['1351220655882479798',
#     '16940164747902333609',
#     '16507853878702409840']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of the muon reconstruction performance of the ATLAS detector using 2011 and 2012 LHC proton–proton collision data',
#     'pub_year': '2014',
#     'citation': 'The European Physical Journal C 74 (11), 1-34, 2014'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:Y5dfb0dijaUC',
#    'num_citations': 1665,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3375542114973672446',
#    'cites_id': ['3375542114973672446']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Jet energy scale measurements and their systematic uncertainties in proton-proton collisions at  with the ATLAS detector',
#     'pub_year': '2017',
#     'citation': 'Physical Review D 96 (7), 072002, 2017'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:isC4tDSrTZIC',
#    'num_citations': 1647,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1297432950916491256',
#    'cites_id': ['1297432950916491256']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Electron reconstruction and identification efficiency measurements with the ATLAS detector using the 2011 LHC proton–proton collision data',
#     'pub_year': '2014',
#     'citation': 'The European Physical Journal C 74 (7), 1-38, 2014'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:EsEWqaRxkBgC',
#    'num_citations': 1605,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10302253069195107950',
#    'cites_id': ['10302253069195107950']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Electron and photon energy calibration with the ATLAS detector using LHC Run 1 data',
#     'pub_year': '2014',
#     'citation': 'The European Physical Journal C 74 (10), 1-48, 2014'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:VjBpw8Hezy4C',
#    'num_citations': 1533,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17112864909752610119',
#    'cites_id': ['17112864909752610119']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Charged-particle multiplicities in pp interactions measured with the ATLAS detector at the LHC',
#     'pub_year': '2010',
#     'citation': 'arXiv preprint arXiv:1012.5104, 2010'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:uk0w_JccWH8C',
#    'num_citations': 1386,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4942477728642957459,3129945993008975896,8267741263162358725',
#    'cites_id': ['4942477728642957459',
#     '3129945993008975896',
#     '8267741263162358725']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Performance of missing transverse momentum reconstruction with the ATLAS detector using proton-proton collisions at  = 13 TeV',
#     'pub_year': '2018',
#     'citation': 'arXiv preprint arXiv:1802.08168, 2018'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:I__7AI8a974C',
#    'num_citations': 1361,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=640471047118349100,3487503261213221302',
#    'cites_id': ['640471047118349100', '3487503261213221302']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of the Z/γ * boson transverse momentum distribution in pp collisions at s = 7  TeV with the ATLAS detector',
#     'pub_year': '2014',
#     'citation': 'Journal of High Energy Physics 2014 (9), 1-47, 2014'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:oldoQiaHq2UC',
#    'num_citations': 1345,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15569096489184432325,8403374151675655725',
#    'cites_id': ['15569096489184432325', '8403374151675655725']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Observation of a Centrality-Dependent Dijet Asymmetry in Lead-Lead Collisions at  with the ATLAS Detector at the LHC',
#     'pub_year': '2010',
#     'citation': 'Physical review letters 105 (25), 252303, 2010'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:CNPyR2KL9-0C',
#    'num_citations': 1319,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10374830077736851981,8047032072306223763,17253654116195546271,13969061008818408898,11291397268823764147',
#    'cites_id': ['10374830077736851981',
#     '8047032072306223763',
#     '17253654116195546271',
#     '13969061008818408898',
#     '11291397268823764147']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Jet energy resolution in proton-proton collisions at  recorded in 2010 with the ATLAS detector',
#     'pub_year': '2013',
#     'citation': 'The European Physical Journal C 73 (3), 1-27, 2013'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:PYBJJbyH-FwC',
#    'num_citations': 1210,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7698947771045836889',
#    'cites_id': ['7698947771045836889']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurements of Higgs boson production and couplings in diboson final states with the ATLAS detector at the LHC',
#     'pub_year': '2013',
#     'citation': 'Physics Letters B 726 (1-3), 88-119, 2013'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:EvHYAMKeY9cC',
#    'num_citations': 1200,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=686220583956310503',
#    'cites_id': ['686220583956310503']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Combined measurement and QCD analysis of the inclusive e±p scattering cross sections at HERA',
#     'pub_year': '2010',
#     'citation': 'Journal of High Energy Physics 2010 (1), 1-63, 2010'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:LimhlhUO2s4C',
#    'num_citations': 1168,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12354853727062846751',
#    'cites_id': ['12354853727062846751']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of the inclusive W±and Z/γ* cross sections in the e and μ decay channels in pp collisions at√ s= 7 TeV with the ATLAS detector',
#     'pub_year': '2012',
#     'citation': 'Physical review. D-particles, fields, gravitation, and cosmology 85 (7), 72004, 2012'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:lvd772isFD0C',
#    'num_citations': 1155,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11951058062555755890,6542920839826731423,15393389361933237369,11113544027654442953,195308422585604028,17089804323296462901,8615251784355694951,17782438671737748997,17675432210292480563,13640645533669328516,10307359120465298924,2986101779777763722',
#    'cites_id': ['11951058062555755890',
#     '6542920839826731423',
#     '15393389361933237369',
#     '11113544027654442953',
#     '195308422585604028',
#     '17089804323296462901',
#     '8615251784355694951',
#     '17782438671737748997',
#     '17675432210292480563',
#     '13640645533669328516',
#     '10307359120465298924',
#     '2986101779777763722']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Performance of b-jet identification in the ATLAS experiment',
#     'pub_year': '2016',
#     'citation': 'Journal of instrumentation 11 (04), P04008, 2016'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:dMyzg-cJZjAC',
#    'num_citations': 1081,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7920769350429880967',
#    'cites_id': ['7920769350429880967']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of the top quark-pair production cross section with ATLAS in pp collisions at   TeV',
#     'pub_year': '2011',
#     'citation': 'The European Physical Journal C 71 (3), 1-36, 2011'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:gmHTDCtJMcoC',
#    'num_citations': 1053,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15215807163219605464,10383628431021041390',
#    'cites_id': ['15215807163219605464', '10383628431021041390']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Search for new phenomena in final states with an energetic jet and large missing transverse momentum in pp collisions at  s = 8 TeV with the ATLAS detector',
#     'pub_year': '2015',
#     'citation': 'The European Physical Journal C 75 (7), 1-43, 2015'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:69viAa4lnfgC',
#    'num_citations': 1028,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13610213769380281300,4432772690270642606,9106637245239668003,9148160859393627472,10200219974726954785,16943075434644897241,3141070965968066508,17900632682394472126,8662284919725525734',
#    'cites_id': ['13610213769380281300',
#     '4432772690270642606',
#     '9106637245239668003',
#     '9148160859393627472',
#     '10200219974726954785',
#     '16943075434644897241',
#     '3141070965968066508',
#     '17900632682394472126',
#     '8662284919725525734']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Search for the  decay of the Standard Model Higgs boson in associated  production with the ATLAS detector',
#     'pub_year': '2014',
#     'citation': 'arXiv preprint arXiv:1409.6212, 2014'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:I858iXPj1OkC',
#    'num_citations': 1001,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13047861336793818538,14102967449355709297,12869168676481023783,7525768067361960516,3488251938203354757,6305990461952991056,15573473254205593667',
#    'cites_id': ['13047861336793818538',
#     '14102967449355709297',
#     '12869168676481023783',
#     '7525768067361960516',
#     '3488251938203354757',
#     '6305990461952991056',
#     '15573473254205593667']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of the inclusive isolated prompt photon cross section in  collisions at  with the ATLAS detector',
#     'pub_year': '2011',
#     'citation': 'Physical Review D 83 (5), 052005, 2011'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:Tk5GfH_nn6kC',
#    'num_citations': 958,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12885597929910716448,6170098930375571803,1469358908763686362,1778336216867395393,14801786484052747225',
#    'cites_id': ['12885597929910716448',
#     '6170098930375571803',
#     '1469358908763686362',
#     '1778336216867395393',
#     '14801786484052747225']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Search for direct production of charginos, neutralinos and sleptons in final states with two leptons and missing transverse momentum in pp collisions at  = 8TeV …',
#     'pub_year': '2014',
#     'citation': 'Journal of High Energy Physics 2014 (5), 1-52, 2014'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:TIZ-Mc8IlK0C',
#    'num_citations': 933,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4564963492334241828,15120391866131972045,9805276634342973596,2674527599327759687,11599743972235292170,2962116341707154725,2951852075389148748',
#    'cites_id': ['4564963492334241828',
#     '15120391866131972045',
#     '9805276634342973596',
#     '2674527599327759687',
#     '11599743972235292170',
#     '2962116341707154725',
#     '2951852075389148748']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Combined search for the Standard Model Higgs boson using up to 4.9 fb− 1 of pp collision data at s= 7TeV with the ATLAS detector at the LHC',
#     'pub_year': '2012',
#     'citation': 'Physics Letters B 710 (1), 49-66, 2012'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:NMlhSUseqAsC',
#    'num_citations': 923,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10402969414863816106,17652960269646199359',
#    'cites_id': ['10402969414863816106', '17652960269646199359']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of inclusive jet and dijet cross sections in proton-proton collisions at 7 TeV centre-of-mass energy with the ATLAS detector',
#     'pub_year': '2010',
#     'citation': 'arXiv preprint arXiv:1009.5908, 2010'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:WbkHhVStYXYC',
#    'num_citations': 915,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1739851329595148043,6090240375447828419,2569567622313453771,13343854724021852423,18432452217614902200,9995002350587704907',
#    'cites_id': ['1739851329595148043',
#     '6090240375447828419',
#     '2569567622313453771',
#     '13343854724021852423',
#     '18432452217614902200',
#     '9995002350587704907']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of the Inelastic Proton-Proton Cross Section at  with the ATLAS Detector at the LHC',
#     'pub_year': '2016',
#     'citation': 'Physical review letters 117 (18), 182002, 2016'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:MTvNnY4oB4UC',
#    'num_citations': 901,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=970675711439997150,461442382330434483',
#    'cites_id': ['970675711439997150', '461442382330434483']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of the azimuthal anisotropy for charged particle production in  TeV lead-lead collisions with the ATLAS detector',
#     'pub_year': '2012',
#     'citation': 'Physical Review C 86 (1), 014907, 2012'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:kVjdVfd2voEC',
#    'num_citations': 866,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7340329841436244653,13976570008197129076',
#    'cites_id': ['7340329841436244653', '13976570008197129076']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'ATLAS pixel detector electronics and sensors',
#     'pub_year': '2008',
#     'citation': 'Journal of instrumentation 3 (07), P07007, 2008'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:tFsQzMahPQAC',
#    'num_citations': 865,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=18054355142190722354',
#    'cites_id': ['18054355142190722354']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Observation of Associated Near-Side and Away-Side Long-Range Correlations in  Proton-Lead Collisions with the ATLAS Detector',
#     'pub_year': '2013',
#     'citation': 'Physical review letters 110 (18), 182302, 2013'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:uWFADo6cQ7YC',
#    'num_citations': 858,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8886099044352269458,303002685002905697,7258117848380699942,18047605515434190333',
#    'cites_id': ['8886099044352269458',
#     '303002685002905697',
#     '7258117848380699942',
#     '18047605515434190333']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Combined measurements of Higgs boson production and decay using up to  of proton-proton collision data at  collected with the ATLAS experiment',
#     'pub_year': '2020',
#     'citation': 'Physical Review D 101 (1), 012002, 2020'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:VBbLNo9YSJgC',
#    'num_citations': 839,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=278015124616932849,7430310890437308534,12464581997980344967,12500631058061309527',
#    'cites_id': ['278015124616932849',
#     '7430310890437308534',
#     '12464581997980344967',
#     '12500631058061309527']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Search for resonances in diphoton events at s = 13  TeV with the ATLAS detector',
#     'pub_year': '2016',
#     'citation': 'Journal of High Energy Physics 2016 (9), 1-50, 2016'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:JWITY9-sCbMC',
#    'num_citations': 828,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=712124182641134346,2064511921140350802,11207634135711919624,11632514037957786295,18165923961991060206,12072414644471483126',
#    'cites_id': ['712124182641134346',
#     '2064511921140350802',
#     '11207634135711919624',
#     '11632514037957786295',
#     '18165923961991060206',
#     '12072414644471483126']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Observation of Higgs boson production in association with a top quark pair at the LHC with the ATLAS detector',
#     'pub_year': '2018',
#     'citation': 'Physics Letters B 784, 173-191, 2018'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:w1MjKQ0l0TYC',
#    'num_citations': 815,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8783002826038810221,17222531865361376889',
#    'cites_id': ['8783002826038810221', '17222531865361376889']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of the  production cross-section using  events with -tagged jets in  collisions at  and 8 TeV with the ATLAS detector',
#     'pub_year': '2014',
#     'citation': 'arXiv preprint arXiv:1406.5375, 2014'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:JO-RqYbuJvsC',
#    'num_citations': 800,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16080590198291579778',
#    'cites_id': ['16080590198291579778']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of Higgs boson production in the diphoton decay channel in  collisions at center-of-mass energies of 7 and 8 TeV with the ATLAS detector',
#     'pub_year': '2014',
#     'citation': 'Physical Review D 90 (11), 112015, 2014'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:4n0clTBhZ78C',
#    'num_citations': 793,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13796558615325602461',
#    'cites_id': ['13796558615325602461']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of the W → ℓν and Z/γ * → ℓℓ production cross sections in proton-proton collisions at  with the ATLAS detector',
#     'pub_year': '2010',
#     'citation': 'Journal of High Energy Physics 2010 (12), 1-65, 2010'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:tz746QTLzJkC',
#    'num_citations': 789,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12417074948295325656,5997537279167094611,4152089236278671509,13889825738455433204,1609576625254678387',
#    'cites_id': ['12417074948295325656',
#     '5997537279167094611',
#     '4152089236278671509',
#     '13889825738455433204',
#     '1609576625254678387']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Search for high-mass diboson resonances with boson-tagged jets in proton-proton collisions at s = 8  TeV with the ATLAS detector',
#     'pub_year': '2015',
#     'citation': 'Journal of High Energy Physics 2015 (12), 1-39, 2015'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:yCjxvIMm6_oC',
#    'num_citations': 768,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17752394524071141314,10816010928215822033,6557379545586365158,13894687351089586026,14974945921336757775,9138447054077190893,16312805139262299772,14277576537702757339,12773806435597657630,6276486241978172944',
#    'cites_id': ['17752394524071141314',
#     '10816010928215822033',
#     '6557379545586365158',
#     '13894687351089586026',
#     '14974945921336757775',
#     '9138447054077190893',
#     '16312805139262299772',
#     '14277576537702757339',
#     '12773806435597657630',
#     '6276486241978172944']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Search for new phenomena in dijet events using 37 fb of  collision data collected at 13 TeV with the ATLAS detector',
#     'pub_year': '2017',
#     'citation': 'arXiv preprint arXiv:1703.09127, 2017'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:BwyfMAYsbu0C',
#    'num_citations': 766,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2704348634375639272,4407229252051017518,15630841046167861054,2773328668229773160,10016801154697037253,16160600997305279997,13551017517688851211,12927544272135860453,8148827642122035767',
#    'cites_id': ['2704348634375639272',
#     '4407229252051017518',
#     '15630841046167861054',
#     '2773328668229773160',
#     '10016801154697037253',
#     '16160600997305279997',
#     '13551017517688851211',
#     '12927544272135860453',
#     '8148827642122035767']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Search for high-mass dilepton resonances in  collisions at  with the ATLAS detector',
#     'pub_year': '2014',
#     'citation': 'Physical Review D 90 (5), 052005, 2014'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:9DLIHnF0jcYC',
#    'num_citations': 735,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11879504827940617539,2490876609784376415',
#    'cites_id': ['11879504827940617539', '2490876609784376415']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Performance of jet substructure techniques for large-R jets in proton-proton collisions at  TeV using the ATLAS detector',
#     'pub_year': '2013',
#     'citation': 'Journal of High Energy Physics 2013 (9), 1-83, 2013'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:UmS_249rOGwC',
#    'num_citations': 733,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9539188164055798361,5315823362755588514,6205062506696950211',
#    'cites_id': ['9539188164055798361',
#     '5315823362755588514',
#     '6205062506696950211']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Erratum to: Study of the spin and parity of the Higgs boson in diboson decays with the ATLAS detector',
#     'pub_year': '2016',
#     'citation': 'The European Physical Journal C 76 (3), 1-14, 2016'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:5zQR9n1GfrwC',
#    'num_citations': 710,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1236799532037089533,6759538061829358557,13899842844115796810,17070666620148473775,49049912091442856,14021294808971623526',
#    'cites_id': ['1236799532037089533',
#     '6759538061829358557',
#     '13899842844115796810',
#     '17070666620148473775',
#     '49049912091442856',
#     '14021294808971623526']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Search for top squark pair production in final states with one isolated lepton, jets, and missing transverse momentum in s  = 8 TeV pp collisions with the ATLAS …',
#     'pub_year': '2014',
#     'citation': 'Journal of High Energy Physics 2014 (11), 1-87, 2014'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:SeFeTyx0c_EC',
#    'num_citations': 709,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16004868427200167838,1756866930925398737,18002360921187857741,17243983379400219694,13569300558140598181,4648217665480549102,7920353628509630080,5417965612022568047',
#    'cites_id': ['16004868427200167838',
#     '1756866930925398737',
#     '18002360921187857741',
#     '17243983379400219694',
#     '13569300558140598181',
#     '4648217665480549102',
#     '7920353628509630080',
#     '5417965612022568047']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Search for squarks and gluinos using final states with jets and missing transverse momentum with the ATLAS detector in s= 7 TeV proton–proton collisions',
#     'pub_year': '2012',
#     'citation': 'Physics Letters B 710 (1), 67-85, 2012'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:SpbeaW3--B0C',
#    'num_citations': 695,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9412179707364787837,15603663823170143616,7429445179160979128,11456571179940732059,1803214969787955841,4355297685926920290',
#    'cites_id': ['9412179707364787837',
#     '15603663823170143616',
#     '7429445179160979128',
#     '11456571179940732059',
#     '1803214969787955841',
#     '4355297685926920290']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Observation of H→ bb decays and VH production with the ATLAS detector',
#     'pub_year': '2018',
#     'citation': 'Physics Letters B 786, 59-86, 2018'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:aU4yMueWZ3QC',
#    'num_citations': 693,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=14664293737099472239,3301128941252599862,16709848247097330156,7464903256076307183',
#    'cites_id': ['14664293737099472239',
#     '3301128941252599862',
#     '16709848247097330156',
#     '7464903256076307183']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Electron and photon performance measurements with the ATLAS detector using the 2015–2017 LHC proton-proton collision data',
#     'pub_year': '2019',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:T64LSalLz9oC',
#    'num_citations': 683,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11886187315746589530',
#    'cites_id': ['11886187315746589530']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Electron reconstruction and identification in the ATLAS experiment using the 2015 and 2016 LHC proton–proton collision data at  s = 13    TeV',
#     'pub_year': '2019',
#     'citation': 'The European Physical Journal C 79 (8), 1-40, 2019'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:yBJCJstOu-sC',
#    'num_citations': 680,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=14315373159840845167',
#    'cites_id': ['14315373159840845167']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Evidence for the H → b b ¯  decay with the ATLAS detector',
#     'pub_year': '2017',
#     'citation': 'Journal of High Energy Physics 2017 (12), 1-71, 2017'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:s85pQhAUCrAC',
#    'num_citations': 661,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10873347191582816312,8089858106391280741,7538474213370556653,6248610888312287569,477730946706464995,17201378409615471669',
#    'cites_id': ['10873347191582816312',
#     '8089858106391280741',
#     '7538474213370556653',
#     '6248610888312287569',
#     '477730946706464995',
#     '17201378409615471669']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'ATLAS b-jet identification performance and efficiency measurement with tt¯ events in pp collisions at s=13 TeV',
#     'pub_year': '2019',
#     'citation': 'The European physical journal C 79 (11), 1-36, 2019'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:0dsCFdkECCQC',
#    'num_citations': 654,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16678347087628840579,7080840268399352499,13709825018553280533',
#    'cites_id': ['16678347087628840579',
#     '7080840268399352499',
#     '13709825018553280533']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurements of Higgs boson production and couplings in the four-lepton channel in  collisions at center-of-mass energies of 7 and 8 TeV with the ATLAS detector',
#     'pub_year': '2014',
#     'citation': 'arXiv preprint arXiv:1408.5191, 2014'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:LkGwnXOMwfcC',
#    'num_citations': 625,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3715185991775597415,297618234248172495',
#    'cites_id': ['3715185991775597415', '297618234248172495']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurements of Higgs boson properties in the diphoton decay channel with  of  collision data at  with the ATLAS detector',
#     'pub_year': '2018',
#     'citation': 'Physical review D 98 (5), 052005, 2018'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:bxPAEoiBajcC',
#    'num_citations': 593,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13486078926882452864,7561168625117612963,2780841022574479363,7692290716622217310,1069418619068534817,10314255598076756834,3272695649374156147',
#    'cites_id': ['13486078926882452864',
#     '7561168625117612963',
#     '2780841022574479363',
#     '7692290716622217310',
#     '1069418619068534817',
#     '10314255598076756834',
#     '3272695649374156147']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Observation and measurement of Higgs boson decays to  with the ATLAS detector',
#     'pub_year': '2014',
#     'citation': 'arXiv preprint arXiv:1412.2641, 2014'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:PQEM9vzQD9gC',
#    'num_citations': 585,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11110408616088227102,12009881148725055218',
#    'cites_id': ['11110408616088227102', '12009881148725055218']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'The ATLAS Inner Detector commissioning and calibration',
#     'pub_year': '2010',
#     'citation': 'The European Physical Journal C 70 (3), 787-821, 2010'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:M0j1y4EgrScC',
#    'num_citations': 579,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15410052704623405648,658452401087147597',
#    'cites_id': ['15410052704623405648', '658452401087147597']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurements of -jet tagging efficiency with the ATLAS detector using  events at  TeV',
#     'pub_year': '2018',
#     'citation': 'arXiv preprint arXiv:1805.01845, 2018'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:uWy0R8PweswC',
#    'num_citations': 568,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5358906953798228771,13639297737306298371,12534589842915785006',
#    'cites_id': ['5358906953798228771',
#     '13639297737306298371',
#     '12534589842915785006']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of the W-boson mass in pp collisions at  s = 7 TeV with the ATLAS detector',
#     'pub_year': '2018',
#     'citation': 'The European Physical Journal C 78 (2), 1-61, 2018'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:lRzkMCTRmMwC',
#    'num_citations': 568,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9654774139322443531,2707420121318746820,7091852319587862709,14171381576148400166,8698972764719502322,6786279203708801979',
#    'cites_id': ['9654774139322443531',
#     '2707420121318746820',
#     '7091852319587862709',
#     '14171381576148400166',
#     '8698972764719502322',
#     '6786279203708801979']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Search for squarks and gluinos with the ATLAS detector in final states with jets and missing transverse momentum using 4.7 fb^-1 of sqrt (s)= 7 TeV proton-proton collision data',
#     'pub_year': '2012',
#     'citation': 'arXiv preprint arXiv:1208.0949, 2012'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:lg2tdxc6qMwC',
#    'num_citations': 543,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1756462165205089129,12038539352388144325,5609887962908968000,10218788828719717826',
#    'cites_id': ['1756462165205089129',
#     '12038539352388144325',
#     '5609887962908968000',
#     '10218788828719717826']},
#   {'container_type': 'Publication',
# ...
#     'pub_year': '2001',
#     'citation': 'Physics Letters B 516 (3-4), 273-292, 2001'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:TAWzVH7WYHIC',
#    'num_citations': 17,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3301337489713402117',
#    'cites_id': ['3301337489713402117']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Determination of the parton distribution functions of the proton using diverse ATLAS data from pp collisions at  s = 7 , 8 and 13 TeV',
#     'pub_year': '2022',
#     'citation': 'The European Physical Journal C 82 (5), 1-70, 2022'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:8eKeg6BV7vYC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8099254474977744252',
#    'cites_id': ['8099254474977744252']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Search for dark matter produced in association with a single top quark in  s = 13  TeV  pp collisions with the ATLAS detector',
#     'pub_year': '2021',
#     'citation': 'The European Physical Journal C 81 (10), 1-37, 2021'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:BJrLMYCRBhgC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13039631484072636621',
#    'cites_id': ['13039631484072636621']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Configuration and performance of the ATLAS -jet triggers in Run 2',
#     'pub_year': '2021',
#     'citation': 'arXiv preprint arXiv:2106.03584, 2021'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:KgZgvZP_DzwC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7851388652048217978,18193674308586182207',
#    'cites_id': ['7851388652048217978', '18193674308586182207']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of the Z (-> l (+) l (-)) gamma production cross-section in pp collisions at root s= 13 TeV with the ATLAS detector',
#     'pub_year': '2020',
#     'citation': 'Journal of High Energy Physics (JHEP), 2020'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:PNc4OtJD23oC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8385778681574580987,16300998838548689534,7043955254556725902',
#    'cites_id': ['8385778681574580987',
#     '16300998838548689534',
#     '7043955254556725902']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of colour flow using jet-pull observables in  t t ¯ events with the ATLAS experiment at  s = 13 TeV',
#     'pub_year': '2018',
#     'citation': 'The European Physical Journal C 78 (10), 1-31, 2018'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:inmFHauC9wsC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7516550550209234574,2900534444395084901,2473780936692033657',
#    'cites_id': ['7516550550209234574',
#     '2900534444395084901',
#     '2473780936692033657']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of the  production cross section in the  + jets final state in  collisions at  TeV using the ATLAS detector',
#     'pub_year': '2017',
#     'citation': 'arXiv preprint arXiv:1702.08839, 2017'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:7T2F9Uy0os0C',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1249269074997454231,3919982733256058266',
#    'cites_id': ['1249269074997454231', '3919982733256058266']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of the cross-section of high transverse momentum vector bosons reconstructed as single jets and studies of jet substructure in pp collisions at= 7 TeV with the …',
#     'pub_year': '2014',
#     'citation': 'New Journal of Physics, 2014'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:iObmAvv4XHcC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11796811256867191705',
#    'cites_id': ['11796811256867191705']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Identification and energy calibration of hadronically decaying tau leptons with the ATLAS experiment in pp collisions at s√= 8 TeV',
#     'pub_year': '2014',
#     'citation': 'Springer, 2014'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:ho-XXoYWL80C',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1012248335565298398',
#    'cites_id': ['1012248335565298398']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Production of the excited charm mesons D1 and D2⁎ at HERA',
#     'pub_year': '2013',
#     'citation': 'Nuclear Physics B 866 (3), 229-254, 2013'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:yhXl426oeGMC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12127959980711643751',
#    'cites_id': ['12127959980711643751']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Search for exotic decays of the Higgs boson into long-lived particles in pp collisions at s  = 13 TeV using displaced vertices in the ATLAS inner detector',
#     'pub_year': '2021',
#     'citation': 'Journal of High Energy Physics 2021 (11), 1-41, 2021'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:JhFzC59B_DkC',
#    'num_citations': 15,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16666943639388072809,9906830143088748977',
#    'cites_id': ['16666943639388072809', '9906830143088748977']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'AtlFast3: the next generation of fast simulation in ATLAS',
#     'pub_year': '2021',
#     'citation': 'arXiv preprint arXiv:2109.02551, 2021'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:9TKaBlIwHecC',
#    'num_citations': 15,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16443839979925221004,4476422065308012086,14692072315655948277',
#    'cites_id': ['16443839979925221004',
#     '4476422065308012086',
#     '14692072315655948277']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Search for phenomena beyond the Standard Model in events with large b-jet multiplicity using the ATLAS detector at the LHC',
#     'pub_year': '2021',
#     'citation': 'The European Physical Journal C 81 (1), 1-29, 2021'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:nwfoItMF7hMC',
#    'num_citations': 15,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=624374609463323975',
#    'cites_id': ['624374609463323975']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Z boson production in Pb+ Pb collisions at sNN= 5.02 TeV measured by the ATLAS experiment',
#     'pub_year': '2020',
#     'citation': 'Physics Letters B 802, 135262, 2020'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:CxegcQ4u50YC',
#    'num_citations': 15,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17805380603419089210',
#    'cites_id': ['17805380603419089210']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Constraints on Higgs boson properties using WW∗(→ eνµν) jj production in 36.1 fb− 1 of√ s= 13 TeV pp collisions with the ATLAS detector',
#     'citation': 'arXiv preprint arXiv:2109.13808, 0'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:YiXZnN5otT4C',
#    'num_citations': 15,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4691895271737292314,4811505062171436537,4571686826646829499',
#    'cites_id': ['4691895271737292314',
#     '4811505062171436537',
#     '4571686826646829499']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of the nuclear modification factor for muons from charm and bottom hadrons in Pb+ Pb collisions at 5.02 TeV with the ATLAS detector',
#     'pub_year': '2022',
#     'citation': 'Physics Letters B 829, 137077, 2022'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:yzEDURfg1-kC',
#    'num_citations': 14,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8507857293951825953',
#    'cites_id': ['8507857293951825953']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Search for supersymmetry in events with four or more charged leptons in 139 fb−1 of s  = 13 TeV pp collisions with the ATLAS detector',
#     'pub_year': '2021',
#     'citation': 'Journal of High Energy Physics 2021 (7), 1-57, 2021'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:X_muxcni1ycC',
#    'num_citations': 14,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1221388420930253336',
#    'cites_id': ['1221388420930253336']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Search for Higgs boson decays into two new low-mass spin-0 particles in the  channel with the ATLAS detector using  collisions at ',
#     'pub_year': '2020',
#     'citation': 'Physical Review D 102 (11), 112006, 2020'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:qStMeLs7OP8C',
#    'num_citations': 14,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17521428510928356548',
#    'cites_id': ['17521428510928356548']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Search for new phenomena in final states with large jet multiplicities and missing transverse momentum using s  = 13 TeV proton-proton collisions recorded by …',
#     'pub_year': '2020',
#     'citation': 'Journal of High Energy Physics 2020 (10), 1-53, 2020'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:0UEzl8ZgZOgC',
#    'num_citations': 14,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11547770873101991898',
#    'cites_id': ['11547770873101991898']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurements of the top quark branching ratios into channels with leptons and quarks with the ATLAS detector',
#     'pub_year': '2015',
#     'citation': 'Physical Review D 92 (7), 072005, 2015'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:HqhvjgTjE9cC',
#    'num_citations': 14,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16204939360696146007,6622669566000610714',
#    'cites_id': ['16204939360696146007', '6622669566000610714']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of the Higgs boson mass from the  and  channels with the ATLAS detector using 25 fb of  collision data',
#     'pub_year': '2014',
#     'citation': 'arXiv preprint arXiv:1406.3827, 2014'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:xyzrkeHX5M4C',
#    'num_citations': 14,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9137294784146488117',
#    'cites_id': ['9137294784146488117']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Multicenter retrospective comparative study of laparoscopically assisted and conventional anorectoplasty for male infants with rectoprostatic urethral fistula',
#     'pub_year': '2013',
#     'citation': 'Journal of Pediatric Surgery 48 (12), 2383-2388, 2013'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:2adpFNImVzkC',
#    'num_citations': 14,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8016604082939548370',
#    'cites_id': ['8016604082939548370']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurement of the W→ τντ cross section in pp collisions at s= 7 TeV with the ATLAS experiment',
#     'pub_year': '2012',
#     'citation': 'Physics Letters B 706 (4-5), 276-294, 2012'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:5MTHONV0fEkC',
#    'num_citations': 14,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6523242399784354856,18082249640512488797,7744743615298044183',
#    'cites_id': ['6523242399784354856',
#     '18082249640512488797',
#     '7744743615298044183']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Properties of hadronic final states in diffractive deep inelastic ep scattering at DESY HERA',
#     'pub_year': '2002',
#     'citation': 'Physical Review D 65 (5), 052001, 2002'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:D2lc7i8A8ooC',
#    'num_citations': 14,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3521130659122441493',
#    'cites_id': ['3521130659122441493']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Search for New Phenomena in Final States with Two Leptons and One or No -Tagged Jets at  Using the ATLAS Detector',
#     'pub_year': '2021',
#     'citation': 'Physical review letters 127 (14), 141801, 2021'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:BxOedqCeNo0C',
#    'num_citations': 13,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12351733858612568029,12822460093442419252',
#    'cites_id': ['12351733858612568029', '12822460093442419252']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Measurements of the production cross-section for a Z boson in association with b-jets in proton-proton collisions at s  = 13 TeV with the ATLAS detector',
#     'pub_year': '2020',
#     'citation': 'Journal of High Energy Physics 2020 (7), 1-58, 2020'},
#    'filled': False,
#    'author_pub_id': 'hBj_cToAAAAJ:SenaEjHFqFYC',
#    'num_citations': 13,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=18003850431566893670,11553058656502862508',
#    'cites_id': ['18003850431566893670', '11553058656502862508']},
#   ...],
#  'public_access': {'available': 1301, 'not_available': 2},
#  'cites_per_year': {2008: 879,
#   2009: 1218,
#   2010: 1918,
#   2011: 4937,
#   2012: 12451,
#   2013: 14825,
#   2014: 15819,
#   2015: 22551,
#   2016: 27359,
#   2017: 26421,
#   2018: 27936,
#   2019: 25917,
#   2020: 21017,
#   2021: 20005,
#   2022: 14807}}
